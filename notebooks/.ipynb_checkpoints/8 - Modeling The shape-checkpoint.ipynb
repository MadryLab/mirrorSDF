# %%
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib.pyplot as plt
import numpy as np
import torch as ch
from tqdm import tqdm

from mirrorSDF.ml_models.embeddings import RandomFourierEmbedding
from mirrorSDF.dataset import MirrorSDFDataset, MirrorSDFDatasetSplit, SamplerWithReplacement
from mirrorSDF.config import MirrorSDFConfig
from mirrorSDF.ml_models import MirrorSDFModel
from mirrorSDF.utils.training import optimizer_from_config
from mirrorSDF.utils.sampling import equi_spaced_samples
from mirrorSDF.utils.light_simulation import mirror_bounce_if_intersects, evaluate_samples_ray
from mirrorSDF.utils.geometry import intersect_with_sphere

from torch.utils.data import DataLoader
# Out:
# /home/guillaumeleclerc/mirrorSDF/mirrorSDF/dataset/dataset.py:5: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
CONFIG_LOCATION = '/data2/keoscope/captures/perfume_three_envs_R6/config.json'
config = MirrorSDFConfig.from_disk(CONFIG_LOCATION)

# %%
model = MirrorSDFModel.from_config(config).cuda()

# %%
dataset = MirrorSDFDataset.from_config(config)
shape_split = MirrorSDFDatasetSplit(dataset, dataset.shape_memmap)
# Out:
# Precomputing ray directions: 0it [00:00, ?it/s]

# %%
first_image = shape_split.extract_single_image(125)
loader = first_image.create_loader(config.pre_training, shuffle=False, device=ch.device('cuda:0'))

# %%
batch = next(iter(loader))

# %%
s = equi_spaced_samples(batch['size'], 8, batch['device'], False)
coords, _ = evaluate_samples_ray(batch, s, foreground=True)
coords_bg, t = evaluate_samples_ray(batch, s, foreground=False)

# %%
sdf, features, gradients, hessian_diagonal = model.sdf(coords, with_grad=True)

# %%
sdf.shape
# Out:
# torch.Size([207, 32, 1])

# %%
random_n = material.env_

# %%
result = []
for batch in tqdm(loader):
    s = equi_spaced_samples(batch['size'], 32, batch['device'], False)
    coords, _ = evaluate_samples_ray(batch, s, foreground=True)
    # coords_bg, t = evaluate_samples_ray(batch, s, foreground=False)
    sdf, features, _, _ = model.sdf(coords)
    result.append(sdf.data.min(1).values.cpu().numpy())
result = np.concatenate(result, axis=0)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 283/283 [00:03<00:00, 70.91it/s]

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 ch
#
# NameError: name 'ch' is not defined

# %%
# %matplotlib notebook

# %%
# %matplotlib notebook

# %%
def plt_sphere(ax, c, r):
    # draw sphere
    u, v = np.mgrid[0:2*np.pi:50j, 0:np.pi:50j]
    x = r*np.cos(u)*np.sin(v)
    y = r*np.sin(u)*np.sin(v)
    z = r*np.cos(v)

    ax.plot_surface(x-c[0], y-c[1], z-c[2], color=np.random.choice(['g','b']), alpha=0.5)

fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(projection='3d')

# circle=plt.Circle((0,0),1)
# plt.gca().add_patch(circle)
ax.scatter(*coords.data.cpu()[0].numpy().T)
# ax.scatter(*coords_bg[0].numpy().T)
plt_sphere(ax, np.zeros(3), 1)

ax.scatter(*batch['origin'][0].cpu().numpy())
ax.set_aspect('equal')
# ax.scatter(*[-6.1731,  1.6173,  3.8220])
# plt.axhline(0)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
res
# Out:
# (577743, 32)

# %%
ground_truth = np.zeros((dataset.image_height, dataset.image_width, 3))
ground_truth[first_image.rows['coord'][:, 1], first_image.rows['coord'][:, 0]] = first_image.rows['measurement']

pred = np.full((dataset.image_height, dataset.image_width, 3), np.nan)
pred[first_image.rows['coord'][:, 1], first_image.rows['coord'][:, 0]] = result[:, 0][:, None]

# %%
plt.figure()
plt.imshow(ground_truth * 10)
plt.imshow(pred[:, :, 0] < 0, alpha=0.5)
plt.xlim(1000, 2000)
plt.ylim(1500, 500)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (1500.0, 500.0)

# %%
plt.figure()
plt.imshow(ground_truth * 10)
plt.imshow(pred[:, :, 0], alpha=0.5)
plt.xlim(1000, 2000)
plt.ylim(1500, 500)
# Out:
# <img src="data:image/png;base64,..." width="640">
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (1500.0, 500.0)

# %%
plt.figure()
plt.imshow(ground_truth * 10)
plt.imshow(pred[:, :, 0], alpha=0.5)
plt.xlim(1000, 2000)
plt.ylim(1500, 500)
# Out:
# <img src="data:image/png;base64,..." width="640">
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (1500.0, 500.0)

# %%
plt.figure()
plt.imshow(ground_truth * 10)
plt.imshow(pred[:, :, 0], alpha=1)
plt.xlim(1000, 2000)
plt.ylim(1500, 500)
# Out:
# <img src="data:image/png;base64,..." width="640">
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (1500.0, 500.0)

# %%
dataset.world_scale_normalization_factor
# Out:
# 0.009605842128561482

# %%
dataset.world_scale_normalization_factor
# Out:
# 0.011764705882352941

# %%
1 / (np.linalg.norm(config.dataset.object_bounding_box) / 2)
# Out:
# 0.013584712216226489

# %%
plt.figure()
plt.imshow(ground_truth * 10)
# Out:
# <img src="data:image/png;base64,..." width="640">
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
X = 100
embedding = RandomFourierEmbedding(3, X, 1, 1000)
model = MLPSDF(width=256, n_layers=5, skip_connections=(4, 6), encoding_features=X, activation=ch.nn.functional.softplus)

# %%
# %matplotlib notebook

# %%
plt.figure()
plt.imshow(pred[:, :,0])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.imshow(ground_truth * 10)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
BS = 200
xes = ch.linspace(-1, 1, BS)
xy = ch.stack([*ch.meshgrid(xes, xes, indexing='ij')], dim=2).reshape(-1, 2)
xyz = ch.concat([xy, xy[:, :1] * 0], 1)
features = embedding(xyz)

# %%
#a = m2(ch.concat([xyz, features * 0], axis=1))
a = model(xyz, features)

# %%
values = a[0].reshape(BS, BS)

# %%
plt.imshow(values.data < 0)

# %%
plt.imshow(values.data)

# %%
plt.plot(xes.data.cpu().numpy(), values.data.min(0).values)
plt.axhline(0)
plt.axvline(-0.5)
plt.axvline(0.5)

# %%
import numpy as np
import torch
import torch.nn.functional as torch_F


class MLPforNeuralSDF(torch.nn.Module):

    def __init__(self, layer_dims, skip_connection=[], activ=None, use_layernorm=False, use_weightnorm=False,
                 geometric_init=False, out_bias=0., invert=False):
        """Initialize a multi-layer perceptron with skip connection.
        Args:
            layer_dims: A list of integers representing the number of channels in each layer.
            skip_connection: A list of integers representing the index of layers to add skip connection.
        """
        super().__init__()
        self.skip_connection = skip_connection
        self.use_layernorm = use_layernorm
        self.linears = torch.nn.ModuleList()
        if use_layernorm:
            self.layer_norm = torch.nn.ModuleList()
        # Hidden layers
        layer_dim_pairs = list(zip(layer_dims[:-1], layer_dims[1:]))
        for li, (k_in, k_out) in enumerate(layer_dim_pairs):
            if li in self.skip_connection:
                k_in += layer_dims[0]
            linear = torch.nn.Linear(k_in, k_out)
            if geometric_init:
                self._geometric_init(linear, k_in, k_out, first=(li == 0),
                                     skip_dim=(layer_dims[0] if li in self.skip_connection else 0))
            if use_weightnorm:
                linear = torch.nn.utils.weight_norm(linear)
            self.linears.append(linear)
            if use_layernorm and li != len(layer_dim_pairs) - 1:
                self.layer_norm.append(torch.nn.LayerNorm(k_out))
            if li == len(layer_dim_pairs) - 1:
                self.linears[-1].bias.data.fill_(0.0)
        # SDF prediction layer
        self.linear_sdf = torch.nn.Linear(k_in, 1)
        if geometric_init:
            self._geometric_init_sdf(self.linear_sdf, k_in, out_bias=out_bias, invert=invert)
        self.activ = activ or torch_F.relu_

    def forward(self, input, with_sdf=True, with_feat=True):
        feat = input
        for li, linear in enumerate(self.linears):
            if li in self.skip_connection:
                feat = torch.cat([feat, input], dim=-1)
            if li != len(self.linears) - 1 or with_feat:
                feat_pre = linear(feat)
                if self.use_layernorm:
                    feat_pre = self.layer_norm[li](feat_pre)
                feat_activ = self.activ(feat_pre)
            if li == len(self.linears) - 1:
                out = [self.linear_sdf(feat) if with_sdf else None,
                       feat_activ if with_feat else None]
            feat = feat_activ
        return out

    def _geometric_init(self, linear, k_in, k_out, first=False, skip_dim=0):
        torch.nn.init.constant_(linear.bias, 0.0)
        torch.nn.init.normal_(linear.weight, 0.0, np.sqrt(2 / k_out))
        if first:
            torch.nn.init.constant_(linear.weight[:, 3:], 0.0)  # positional encodings
        if skip_dim:
            torch.nn.init.constant_(linear.weight[:, -skip_dim:], 0.0)  # skip connections

    def _geometric_init_sdf(self, linear, k_in, out_bias=0., invert=False):
        torch.nn.init.normal_(linear.weight, mean=np.sqrt(np.pi / k_in), std=0.0001)
        torch.nn.init.constant_(linear.bias, -out_bias)
        if invert:
            linear.weight.data *= -1
            linear.bias.data *= -1
